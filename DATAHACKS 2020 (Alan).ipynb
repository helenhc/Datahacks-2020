# %%
import os
import pandas as pd
import numpy as np

# %%
barts_hotspot = os.path.join('barts_hotspots.csv')
barts_to_all = os.path.join('barts_to_all.csv')
hotspot = os.path.join('hotspots_to_all.csv')
q1 = os.path.join('hours_q1.csv')
q2 = os.path.join('hours_q2.csv')

barts_hotspots = pd.read_csv(barts_hotspot)
barts_to_all = pd.read_csv(barts_to_all)
hotspots_to_all = pd.read_csv(hotspot)
hours_q1 = pd.read_csv(q1)
hours_q2 = pd.read_csv(q2)

# %%
barts_hotspots['Destination Display Name'] = barts_hotspots['Destination Display Name'].replace("Fisherman's Wharf, San Francisco, CA","Fisherman's Wharf, 286-298 Jefferson St, San Francisco, CA")

# %%
# column_vals = barts_hotspot.columns.values[5:]
# for i in column_vals: 
#     barts_hotspot[i] = barts_hotspot.groupby(['Origin Movement ID', 'Destination Movement ID']).transform(lambda x: x.fillna(x.mean()))

# %%
barts = barts_to_all['Origin Display Name'].unique()
barts_to_hotspots = barts_hotspots[(barts_hotspots['Origin Display Name'] == barts[0]) | (barts_hotspots['Origin Display Name'] == barts[1]) | (barts_hotspots['Origin Display Name'] == barts[2])]

# %%
barts_to_hotspots.head()
# Out:
#          Date  Origin Movement ID             Origin Display Name  \
# 1  04/28/2019                3603  Embarcadero, San Francisco, CA
# 2  05/18/2019                3603  Embarcadero, San Francisco, CA
# 6  04/23/2019                3603  Embarcadero, San Francisco, CA
# 7  05/13/2019                3603  Embarcadero, San Francisco, CA
# 9  04/14/2019                3603  Embarcadero, San Francisco, CA
#
#    Destination Movement ID                           Destination Display Name  \
# 1                     3394  Fisherman's Wharf, 286-298 Jefferson St, San F...
# 2                     3394  Fisherman's Wharf, 286-298 Jefferson St, San F...
# 6                     3394  Fisherman's Wharf, 286-298 Jefferson St, San F...
# 7                     3394  Fisherman's Wharf, 286-298 Jefferson St, San F...
# 9                     3396  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
#
#    Daily Mean Travel Time (Seconds)  \
# 1                             639.0
# ...

# %%
barts_to_hotspots[['Origin Display Name', 'Destination Display Name', 'Daily Mean Travel Time (Seconds)']].groupby(['Origin Display Name', 'Destination Display Name']).mean()
# Out:
#                                                                                                        Daily Mean Travel Time (Seconds)
# Origin Display Name                                Destination Display Name
# 2nd Street and Stevenson Street (Montgomery BAR... Fisherman's Wharf, 286-298 Jefferson St, San Fr...                        788.508287
#                                                    Oracle Park, 24 Willie Mays Plaza, San Francisc...                        481.983425
#                                                    The Palace Of Fine Arts, 3601 Lyon St, San Fran...                       1285.455556
# Embarcadero, San Francisco, CA                     Fisherman's Wharf, 286-298 Jefferson St, San Fr...                        665.077348
#                                                    Oracle Park, 24 Willie Mays Plaza, San Francisc...                        579.160221
# ...

# %%
# barts_ids = {'Embarcadero, San Francisco, CA': 3603, '2nd Street and Stevenson Street (Montgomery BART, San Francisco, CA': 3692, 'Powell BART Station, Market St and Powell St, San Francisco, CA': 3760}
# hotspots_ids = {'The Palace Of Fine Arts, 3601 Lyon St, San Francisco, CA': 3396, 'Oracle Park, 24 Willie Mays Plaza, San Francisco, CA': 3792, "Fisherman's Wharf, 286-298 Jefferson St, San Francisco, CA": 3394}

# %%
emb_fish_am_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['AM Mean Travel Time (Seconds)'].mean()
emb_pal_am_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['AM Mean Travel Time (Seconds)'].mean()
emb_ora_am_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['AM Mean Travel Time (Seconds)'].mean()
pow_fish_am_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['AM Mean Travel Time (Seconds)'].mean()
pow_pal_am_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['AM Mean Travel Time (Seconds)'].mean()
pow_ora_am_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['AM Mean Travel Time (Seconds)'].mean()
mon_fish_am_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['AM Mean Travel Time (Seconds)'].mean()
mon_pal_am_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['AM Mean Travel Time (Seconds)'].mean()
mon_ora_am_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['AM Mean Travel Time (Seconds)'].mean()
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'AM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'AM Mean Travel Time (Seconds)'].fillna(emb_fish_am_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'AM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'AM Mean Travel Time (Seconds)'].fillna(emb_pal_am_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'AM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'AM Mean Travel Time (Seconds)'].fillna(emb_ora_am_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'AM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'AM Mean Travel Time (Seconds)'].fillna(pow_fish_am_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'AM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'AM Mean Travel Time (Seconds)'].fillna(pow_pal_am_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'AM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'AM Mean Travel Time (Seconds)'].fillna(pow_ora_am_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'AM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'AM Mean Travel Time (Seconds)'].fillna(mon_fish_am_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'AM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'AM Mean Travel Time (Seconds)'].fillna(mon_pal_am_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'AM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'AM Mean Travel Time (Seconds)'].fillna(mon_ora_am_mean)

emb_fish_pm_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['PM Mean Travel Time (Seconds)'].mean()
emb_pal_pm_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['PM Mean Travel Time (Seconds)'].mean()
emb_ora_pm_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['PM Mean Travel Time (Seconds)'].mean()
pow_fish_pm_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['PM Mean Travel Time (Seconds)'].mean()
pow_pal_pm_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['PM Mean Travel Time (Seconds)'].mean()
pow_ora_pm_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['PM Mean Travel Time (Seconds)'].mean()
mon_fish_pm_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['PM Mean Travel Time (Seconds)'].mean()
mon_pal_pm_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['PM Mean Travel Time (Seconds)'].mean()
mon_ora_pm_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['PM Mean Travel Time (Seconds)'].mean()
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'PM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'PM Mean Travel Time (Seconds)'].fillna(emb_fish_pm_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'PM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'PM Mean Travel Time (Seconds)'].fillna(emb_pal_pm_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'PM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'PM Mean Travel Time (Seconds)'].fillna(emb_ora_pm_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'PM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'PM Mean Travel Time (Seconds)'].fillna(pow_fish_pm_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'PM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'PM Mean Travel Time (Seconds)'].fillna(pow_pal_pm_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'PM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'PM Mean Travel Time (Seconds)'].fillna(pow_ora_pm_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'PM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'PM Mean Travel Time (Seconds)'].fillna(mon_fish_pm_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'PM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'PM Mean Travel Time (Seconds)'].fillna(mon_pal_pm_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'PM Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'PM Mean Travel Time (Seconds)'].fillna(mon_ora_pm_mean)

emb_fish_mid_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['Midday Mean Travel Time (Seconds)'].mean()
emb_pal_mid_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['Midday Mean Travel Time (Seconds)'].mean()
emb_ora_mid_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['Midday Mean Travel Time (Seconds)'].mean()
pow_fish_mid_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['Midday Mean Travel Time (Seconds)'].mean()
pow_pal_mid_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['Midday Mean Travel Time (Seconds)'].mean()
pow_ora_mid_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['Midday Mean Travel Time (Seconds)'].mean()
mon_fish_mid_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['Midday Mean Travel Time (Seconds)'].mean()
mon_pal_mid_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['Midday Mean Travel Time (Seconds)'].mean()
mon_ora_mid_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['Midday Mean Travel Time (Seconds)'].mean()
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Midday Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Midday Mean Travel Time (Seconds)'].fillna(emb_fish_mid_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Midday Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Midday Mean Travel Time (Seconds)'].fillna(emb_pal_mid_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Midday Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Midday Mean Travel Time (Seconds)'].fillna(emb_ora_mid_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Midday Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Midday Mean Travel Time (Seconds)'].fillna(pow_fish_mid_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Midday Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Midday Mean Travel Time (Seconds)'].fillna(pow_pal_mid_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Midday Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Midday Mean Travel Time (Seconds)'].fillna(pow_ora_mid_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Midday Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Midday Mean Travel Time (Seconds)'].fillna(mon_fish_mid_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Midday Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Midday Mean Travel Time (Seconds)'].fillna(mon_pal_mid_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Midday Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Midday Mean Travel Time (Seconds)'].fillna(mon_ora_mid_mean)

emb_fish_eve_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['Evening Mean Travel Time (Seconds)'].mean()
emb_pal_eve_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['Evening Mean Travel Time (Seconds)'].mean()
emb_ora_eve_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['Evening Mean Travel Time (Seconds)'].mean()
pow_fish_eve_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['Evening Mean Travel Time (Seconds)'].mean()
pow_pal_eve_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['Evening Mean Travel Time (Seconds)'].mean()
pow_ora_eve_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['Evening Mean Travel Time (Seconds)'].mean()
mon_fish_eve_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['Evening Mean Travel Time (Seconds)'].mean()
mon_pal_eve_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['Evening Mean Travel Time (Seconds)'].mean()
mon_ora_eve_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['Evening Mean Travel Time (Seconds)'].mean()
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Evening Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Evening Mean Travel Time (Seconds)'].fillna(emb_fish_eve_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Evening Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Evening Mean Travel Time (Seconds)'].fillna(emb_pal_eve_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Evening Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Evening Mean Travel Time (Seconds)'].fillna(emb_ora_eve_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Evening Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Evening Mean Travel Time (Seconds)'].fillna(pow_fish_eve_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Evening Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Evening Mean Travel Time (Seconds)'].fillna(pow_pal_eve_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Evening Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Evening Mean Travel Time (Seconds)'].fillna(pow_ora_eve_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Evening Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Evening Mean Travel Time (Seconds)'].fillna(mon_fish_eve_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Evening Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Evening Mean Travel Time (Seconds)'].fillna(mon_pal_eve_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Evening Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Evening Mean Travel Time (Seconds)'].fillna(mon_ora_eve_mean)

emb_fish_em_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['Early Morning Mean Travel Time (Seconds)'].mean()
emb_pal_em_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['Early Morning Mean Travel Time (Seconds)'].mean()
emb_ora_em_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['Early Morning Mean Travel Time (Seconds)'].mean()
pow_fish_em_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['Early Morning Mean Travel Time (Seconds)'].mean()
pow_pal_em_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['Early Morning Mean Travel Time (Seconds)'].mean()
pow_ora_em_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['Early Morning Mean Travel Time (Seconds)'].mean()
mon_fish_em_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394)]['Early Morning Mean Travel Time (Seconds)'].mean()
mon_pal_em_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396)]['Early Morning Mean Travel Time (Seconds)'].mean()
mon_ora_em_mean = barts_to_hotspots[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792)]['Early Morning Mean Travel Time (Seconds)'].mean()
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Early Morning Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Early Morning Mean Travel Time (Seconds)'].fillna(emb_fish_em_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Early Morning Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Early Morning Mean Travel Time (Seconds)'].fillna(emb_pal_em_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Early Morning Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3603) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Early Morning Mean Travel Time (Seconds)'].fillna(emb_ora_em_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Early Morning Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Early Morning Mean Travel Time (Seconds)'].fillna(pow_fish_em_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Early Morning Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Early Morning Mean Travel Time (Seconds)'].fillna(pow_pal_em_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Early Morning Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3760) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Early Morning Mean Travel Time (Seconds)'].fillna(pow_ora_em_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Early Morning Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3394), 'Early Morning Mean Travel Time (Seconds)'].fillna(mon_fish_em_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Early Morning Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3396), 'Early Morning Mean Travel Time (Seconds)'].fillna(mon_pal_em_mean)
barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Early Morning Mean Travel Time (Seconds)'] = barts_to_hotspots.loc[(barts_to_hotspots['Origin Movement ID'] == 3692) & (barts_to_hotspots['Destination Movement ID'] == 3792), 'Early Morning Mean Travel Time (Seconds)'].fillna(mon_ora_em_mean)
# Out:
# /home/alanlam00/miniconda3/envs/ds/lib/python3.8/site-packages/pandas/core/indexing.py:964: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
print(sum(barts_to_hotspots['AM Mean Travel Time (Seconds)'].isna()))
print(sum(barts_to_hotspots['PM Mean Travel Time (Seconds)'].isna()))
print(sum(barts_to_hotspots['Midday Mean Travel Time (Seconds)'].isna()))
print(sum(barts_to_hotspots['Evening Mean Travel Time (Seconds)'].isna()))
print(sum(barts_to_hotspots['Early Morning Mean Travel Time (Seconds)'].isna()))
# Out:
# 0
# 0
# 0
# 0
# 543

# %%
barts_to_hotspots[['Origin Display Name', 'Destination Display Name', 'Daily Mean Travel Time (Seconds)', 'AM Mean Travel Time (Seconds)', 'PM Mean Travel Time (Seconds)', 'Midday Mean Travel Time (Seconds)', 'Evening Mean Travel Time (Seconds)', 'Early Morning Mean Travel Time (Seconds)']].groupby(['Origin Display Name', 'Destination Display Name']).mean()
# Out:
#                                                                                                        Daily Mean Travel Time (Seconds)  \
# Origin Display Name                                Destination Display Name
# 2nd Street and Stevenson Street (Montgomery BAR... Fisherman's Wharf, 286-298 Jefferson St, San Fr...                        788.508287
#                                                    Oracle Park, 24 Willie Mays Plaza, San Francisc...                        481.983425
#                                                    The Palace Of Fine Arts, 3601 Lyon St, San Fran...                       1285.455556
# Embarcadero, San Francisco, CA                     Fisherman's Wharf, 286-298 Jefferson St, San Fr...                        665.077348
#                                                    Oracle Park, 24 Willie Mays Plaza, San Francisc...                        579.160221
# ...
